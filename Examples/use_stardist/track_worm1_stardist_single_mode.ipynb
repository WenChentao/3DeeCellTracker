# %% [markdown]
# # 3DeeCellTracker Demo: Single mode | Use StarDist
#
# This notebook shows how to use 3DeeCellTracker to track cells in single mode. The segmentation is basded on the trained StarDist.
#
# The demo data can be found in the "single_mode_worm1" folder downloaded from https://osf.io/pgr95/
#
# **The basic procedures:**
# - A. Import packages
# - B. Segment cells by StarDist3D
# - C. Load manually corrected segmentation (t=1)
# - D. Track cells by FFN + PRGLS + Fine-tune.
# - E. Extract activities from the tracked cells.

# %% [markdown]
# ## A. Import packages

# %%
# %load_ext autoreload
# %autoreload 2
import os
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# %matplotlib inline
import numpy as np

import CellTracker.trackerlite as trl
import CellTracker.stardistwrapper as sdw
import CellTracker.coord_image_transformer as cit
from CellTracker.analyses import draw_signals
# Out:
# <style>.container { width:95% !important; }</style>
# 2023-04-24 09:57:56.988133: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ## B. Segment cells by StarDist3D
# ### B.1 Load the trained StarDist3D model
#
# ### Parameters
# - `model_name`: A string specifying the model name set during training session. The program will automatically search for it.

# %%
stardist_model_name = "stardist_worm1"

model = sdw.load_stardist_model(model_name=stardist_model_name)
# Out:
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.537581, nms_thresh=0.3.
# Load pretrained stardist model 'stardist_worm1' from folder 'stardist_models'
# 2023-04-24 09:57:57.651433: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-04-24 09:57:57.715710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.716126: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3080 Ti computeCapability: 8.6
# coreClock: 1.665GHz coreCount: 80 deviceMemorySize: 11.76GiB deviceMemoryBandwidth: 849.46GiB/s
# 2023-04-24 09:57:57.716146: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-24 09:57:57.717246: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-04-24 09:57:57.717274: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-04-24 09:57:57.717657: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-04-24 09:57:57.717754: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-04-24 09:57:57.718753: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-04-24 09:57:57.718986: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-04-24 09:57:57.719059: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-04-24 09:57:57.719113: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.719540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.719930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-04-24 09:57:57.720668: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 09:57:57.721118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.721638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3080 Ti computeCapability: 8.6
# coreClock: 1.665GHz coreCount: 80 deviceMemorySize: 11.76GiB deviceMemoryBandwidth: 849.46GiB/s
# 2023-04-24 09:57:57.721865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.722364: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.722762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-04-24 09:57:57.722812: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-24 09:57:57.977463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-04-24 09:57:57.977484: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-04-24 09:57:57.977487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-04-24 09:57:57.977634: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.978024: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.978387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-24 09:57:57.978728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10033 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6)

# %% [markdown]
# ### Segment the volume #1 image and save the results as tiff images

# %%
# Set the initial volume number
vol = 1

path_results = "./worm1/"

# Set the file path for the raw images
path_raw_images = "./worm1/data/*t%03d*.tif"

# Load 2D slices of the image stack at the current volume
x = sdw.load_2d_slices_at_time(slice_paths=path_raw_images, t=vol)

# Get the shape of the loaded images
image_shape = x.shape
print(f"{image_shape=}")

# Predict instance labels and details using a trained model
(labels, details), prob_map = model.predict_instances(x)
print(f"{prob_map.shape=}")

# ys = model.keras_model.predict(x[None,:,:,:])
# print(ys[0])

# Plot the maximum projection of the predicted instance labels
sdw.plot_img_label_max_projection(x, labels, lbl_title="label pred (projection)", fig_width_px=1800)

# Determine whether to use 8-bit or 16-bit image format
use_8_bit = True if labels.max() <= 255 else False
# Out:
# image_shape=(21, 512, 1024)
# 2023-04-24 09:58:03.359213: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-04-24 09:58:03.376936: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3504000000 Hz
# 2023-04-24 09:58:03.661377: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-04-24 09:58:04.003256: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8101
# 2023-04-24 09:58:04.598237: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-04-24 09:58:04.884236: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# prob_map.shape=(21, 256, 512)

# %%
sdw.plot_img_label_max_projection_xz(x, labels, lbl_title="label pred (projection)", fig_width_px=1800, scale_z=9)

# %% [markdown]
# ### Segment all volumes and save the coordinates of predicted cell centers

# %%
sdw.predict_and_save(images_path=path_raw_images, model=model, results_folder=path_results)
# Out:
# Segmenting images: 100%|█| 50/50 [01:35<00:00,  1.
# All images from t=1 to t=50 have been Segmented

# %% [markdown]
# ## C. Manually correct the segmentation at volume 1 and load it.
#
# **C1. Manual correction and move files to the folder**
# - Delete non-cell regions;
# - Add cells not labeled;
# - correct cell boundaries in other software (such as ITK-SNAP)
#
# - save the corrected segmentation as 2D images (with different z)
# - Move the corrected segmentation to the created "/manual_vol1" folder

# %% [markdown]
# **C2. Load the manually corrected segmentation**

# %%
voxel_size=(1, 1, 9.2)
manual_seg_path="./worm1/manual_vol1/*.tif"

coords2image = cit.CoordsToImageTransformer(results_folder=path_results, voxel_size=voxel_size)
coords2image.load_segmentation(manual_vol1_path=manual_seg_path)
sdw.plot_img_label_max_projection(x, coords2image.proofed_segmentation.transpose(2,0,1), lbl_title="label proofed (projection)", fig_width_px=1800)
# Out:
# Loaded the proofed segmentations at vol 1 with 164 cells

# %%
sdw.plot_img_label_max_projection_xz(x, coords2image.proofed_segmentation.transpose(2,0,1), lbl_title="label proofed (projection)", fig_width_px=1800, scale_z=9.2)

# %% [markdown]
# **C3. Interpolate cells to make more smooth cell boundary**

# %%
coords2image.interpolate(interpolation_factor=10)
# Out:
# Interpolating images along z-axis...
# The interpolated segmentations at vol 1 contains 164 cells
# Calculating coordinates of cell centers...

# %%
sdw.plot_img_label_max_projection(x, coords2image.auto_corrected_segmentation.transpose(2,0,1), lbl_title="label interpolated (projection)", fig_width_px=1800)

# %%
sdw.plot_img_label_max_projection_xz(x, coords2image.auto_corrected_segmentation.transpose(2,0,1), lbl_title="label interpolated (projection)", fig_width_px=1800,scale_z=9.2)

# %% [markdown]
# ## D. Tracking cells.
# **D1. Set paths**

# %%
ffn_model_name="ffn_worm3"

tracker = trl.TrackerLite(results_dir=path_results, ffn_model_name=ffn_model_name, proofed_coords_vol1=coords2image.coord_vol1)
# Out:
# 2023-04-24 10:02:01.996790: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %% [markdown]
#  **D2. Test ffn matching**

# %%
tracker.match_by_ffn(t1=1, t2=50)

# %% [markdown]
# **D3. Test FFN + PR-GLS prediction**

# %%
beta, lambda_= (3, 3)

tracked_positions_t2 = tracker.predict_cell_positions(t1=1, t2=50, beta=lambda_, lambda_=beta, draw_fig=True)

# %% [markdown]
# **D4. Track all following volumes**

# %%
t_start, t_end = (1, 50)
skipped_volumes = []
ensemble = False

t1 = t_start
confirmed_coord = coords2image.coord_vol1
grid = model.config.grid
for t in range(t_start+1, t_end+1):
    print(f"t={t}...", end="\r")
    if t in skipped_volumes:
        print(f"skip t={t}")
        continue
    coord_prgls = tracker.predict_cell_positions(t1=t1, t2=t, confirmed_coord_t1=confirmed_coord, beta=beta, lambda_=lambda_, draw_fig=False)
    confirmed_coord, corrected_labels_image = coords2image.accurate_correction(t, grid, coord_prgls, ensemble=ensemble)
    coords2image.save_tracking_results(confirmed_coord, corrected_labels_image, tracker, t1=t1, t2=t, images_path=path_raw_images)
    t1 = t
# Out:
# t=50...

# %% [markdown]
# ## E. Extract activities from tracked cells

# %% [markdown]
# ### Purpose
# This Code Block extracts activities from 3D time-lapse images, based on tracking results. The activities are calculated for each cell detected in the image data.
#
# ### Parameters
# - `raw_path`: A string specifying the file path to the image data to be analyzed. The image data should be in TIFF format, with each image representing a 2D slice of a 3D image at a specific time point 't'. The file name must follow a specific format, such as "*t%03d*.tif" or "*t%04d*.tif", where the '*' characters indicate any number of characters.The '%03d' or '%04d' format specifier is a special string formatting syntax in Python that specifies a zero-padded, 3-digit or 4-digit integer.

# %%
raw_path = "./worm1/data/*t%03d*.tif"

activities = tracker.activities(raw_path=raw_path)
# Out:
# t=50...

# %% [markdown]
# **Draw a figure to show the activities**

# %%
draw_signals(activities, ylim_lower=0, ylim_upper=2, figsize=(20, 10))

# %% [markdown]
# **Export the activities as csv file**

# %%
csv_filename = os.path.join(path_results, "activities_txcell.csv")
timings = np.arange(1, activities.shape[0]+1).reshape(-1, 1)
activities_with_timings = np.concatenate((timings, activities), axis=1)
headers = ['timing'] + ['cell' + str(i) for i in range(1, activities.shape[1]+1)]
np.savetxt(csv_filename, activities_with_timings, delimiter=',', fmt='%.3f', header=','.join(headers), comments='')
print(f"The cell activities have been saved in {csv_filename}")
# Out:
# The cell activities have been saved in ./worm1/activities_txcell.csv
