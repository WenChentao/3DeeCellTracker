# %% [markdown]
# # 3DeeCellTracker Demo: Train FlexiblePointMatcher with a .csv file
#
# This notebook shows how to train a neural network called FlexiblePointMatching for 3D cell tracking.
#
# To get started, you can download the "worm3_points_t1.csv" file from our GitHub repository at https://github.com/WenChentao/3DeeCellTracker/blob/master/Examples/use_stardist/worm3_points_t1.csv. This file will be used throughout the notebook to showcase the FFN training process. Alternatively, you can generate your own 3D cell coordinates in a .csv file to train your own model.
#
# **The basic procedures:**
# - A. Import packages
# - B. Initialize the trainer
# - C. Train FPM

# %% [markdown]
# ## A. Import packages

# %%
# %load_ext autoreload
# %autoreload 
from CellTracker.fpm import TrainFPM, FlexiblePointMatcherAdd

# %% [markdown]
# ## B. Initialize the trainer
#
# ### Parameters
# - `points_path`: A string that specifies the path to the .csv file containing the 3D cell coordinates.
# - `model_name`: A string specifying the name of the ffn model to save. This name will be used to load the model later.
#
# ### Notes:
# > By default, the trained model will be saved in the "ffn_models" directory. If you want to save the model in a different location, you can specify the basedir parameter and provide the directory path.
# ```
#     ffn_trainer = TrainFFN(points1_path=points_path, model_name=model_name, basedir=".\FolderA\FolderB\")
# ```

# %% [markdown]
# ## C. Train FFN
#
# ### Parameters
# - `num_epochs`: An integer specifying the number of epochs for training. A larger number of epochs will require a longer training time. The default value of 100 is a reasonable choice.

# %%
points_path="./worm3_points_t1.csv"
model_name="fpm_add_2skip_worm3_180_deg"
deg = 180
num_epochs=100
match_model = FlexiblePointMatcherAdd(num_skip=2)

fpm_trainer = TrainFPM(points1_path=points_path, match_model=match_model, model_name=model_name, 
                       range_rotation_tgt=deg)
fpm_trainer.train(num_epochs=num_epochs, iteration=5000)
# Out:
# 2023-07-04 16:21:36.121650: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.132851: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.133576: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.134938: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-04 16:21:36.136050: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.136683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.137212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.378323: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.378742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.379114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-07-04 16:21:36.379464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10035 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/100:   0%|    | 0/5000 [00:00<?, ?batch/s]2023-07-04 16:21:36.904272: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8101
# 2023-07-04 16:21:37.594159: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 1/100: 5001batch [01:54, 43.53batch/s, Train Accuracy=0.879, Train loss=0.194]
# Epoch 2/100: 5001batch [01:53, 44.04batch/s, Train Accuracy=0.925, Train loss=0.154]
# Epoch 3/100: 5001batch [01:53, 43.99batch/s, Train Accuracy=0.931, Train loss=0.144]
# Epoch 4/100: 5001batch [01:54, 43.82batch/s, Train Accuracy=0.935, Train loss=0.131]
# Epoch 5/100: 5001batch [01:54, 43.52batch/s, Train Accuracy=0.939, Train loss=0.124]
# Epoch 6/100: 5001batch [01:55, 43.14batch/s, Train Accuracy=0.941, Train loss=0.117]
# Epoch 7/100: 5001batch [01:54, 43.69batch/s, Train Accuracy=0.943, Train loss=0.113]
# Epoch 8/100: 5001batch [01:54, 43.58batch/s, Train Accuracy=0.945, Train loss=0.11]
# Epoch 9/100: 5001batch [01:53, 43.90batch/s, Train Accuracy=0.946, Train loss=0.11]
# Epoch 10/100: 5001batch [01:53, 43.87batch/s, Train Accuracy=0.948, Train loss=0.104]
# Epoch 11/100: 5001batch [01:54, 43.77batch/s, Train Accuracy=0.949, Train loss=0.104]
# Epoch 12/100: 5001batch [01:53, 43.87batch/s, Train Accuracy=0.95, Train loss=0.106]
# Epoch 13/100: 5001batch [01:53, 43.90batch/s, Train Accuracy=0.951, Train loss=0.0991]
# Epoch 14/100: 5001batch [01:54, 43.75batch/s, Train Accuracy=0.951, Train loss=0.0998]
# Epoch 15/100: 5001batch [01:53, 43.90batch/s, Train Accuracy=0.952, Train loss=0.099]
# Epoch 16/100: 5001batch [01:54, 43.85batch/s, Train Accuracy=0.953, Train loss=0.0999]
# Epoch 17/100: 5001batch [01:54, 43.81batch/s, Train Accuracy=0.953, Train loss=0.1]
# Epoch 18/100: 5001batch [01:54, 43.78batch/s, Train Accuracy=0.953, Train loss=0.0989]
# Epoch 19/100: 5001batch [01:53, 43.88batch/s, Train Accuracy=0.954, Train loss=0.0965]
# Epoch 20/100: 5001batch [01:54, 43.84batch/s, Train Accuracy=0.954, Train loss=0.0988]
# Epoch 21/100: 5001batch [01:54, 43.76batch/s, Train Accuracy=0.955, Train loss=0.0961]
# Epoch 22/100: 5001batch [01:54, 43.85batch/s, Train Accuracy=0.955, Train loss=0.0972]
# Epoch 23/100: 5001batch [01:54, 43.54batch/s, Train Accuracy=0.955, Train loss=0.0944]
# Epoch 24/100: 5001batch [01:55, 43.40batch/s, Train Accuracy=0.956, Train loss=0.0955]
# Epoch 25/100: 5001batch [01:53, 44.09batch/s, Train Accuracy=0.956, Train loss=0.0965]
# Epoch 26/100: 5001batch [01:51, 44.93batch/s, Train Accuracy=0.956, Train loss=0.0957]
# Epoch 27/100: 5001batch [01:51, 45.03batch/s, Train Accuracy=0.956, Train loss=0.0933]
# Epoch 28/100: 5001batch [01:51, 44.95batch/s, Train Accuracy=0.957, Train loss=0.0933]
# Epoch 29/100: 5001batch [01:51, 45.02batch/s, Train Accuracy=0.957, Train loss=0.0925]
# Epoch 30/100: 5001batch [01:51, 44.97batch/s, Train Accuracy=0.957, Train loss=0.0927]
# Epoch 31/100: 5001batch [01:51, 44.93batch/s, Train Accuracy=0.957, Train loss=0.0925]
# Epoch 32/100: 5001batch [01:51, 45.00batch/s, Train Accuracy=0.958, Train loss=0.0944]
# Epoch 33/100: 5001batch [01:51, 44.94batch/s, Train Accuracy=0.958, Train loss=0.0875]
# Epoch 34/100: 5001batch [01:51, 45.00batch/s, Train Accuracy=0.958, Train loss=0.0909]
# Epoch 35/100: 5001batch [01:51, 44.98batch/s, Train Accuracy=0.958, Train loss=0.093]
# Epoch 36/100: 5001batch [01:51, 45.02batch/s, Train Accuracy=0.958, Train loss=0.0925]
# Epoch 37/100: 5001batch [01:51, 44.93batch/s, Train Accuracy=0.959, Train loss=0.095]
# Epoch 38/100: 5001batch [01:51, 44.97batch/s, Train Accuracy=0.959, Train loss=0.0876]
# Epoch 39/100: 5001batch [01:51, 45.01batch/s, Train Accuracy=0.959, Train loss=0.091]
# Epoch 40/100: 5001batch [01:51, 45.01batch/s, Train Accuracy=0.959, Train loss=0.0905]
# Epoch 41/100: 5001batch [01:51, 45.02batch/s, Train Accuracy=0.959, Train loss=0.0929]
# Epoch 42/100: 5001batch [01:51, 44.92batch/s, Train Accuracy=0.959, Train loss=0.0902]
# Epoch 43/100: 5001batch [01:51, 45.00batch/s, Train Accuracy=0.959, Train loss=0.0921]
# Epoch 44/100: 5001batch [01:51, 44.96batch/s, Train Accuracy=0.96, Train loss=0.0891]
# Epoch 45/100: 5001batch [01:51, 45.01batch/s, Train Accuracy=0.96, Train loss=0.0896]
# Epoch 46/100: 5001batch [01:51, 45.00batch/s, Train Accuracy=0.96, Train loss=0.0929]
# Epoch 47/100: 5001batch [01:51, 44.90batch/s, Train Accuracy=0.96, Train loss=0.0906]
# Epoch 48/100: 5001batch [01:51, 45.04batch/s, Train Accuracy=0.96, Train loss=0.0921]
# Epoch 49/100: 5001batch [01:51, 44.89batch/s, Train Accuracy=0.96, Train loss=0.0898]
# Epoch 50/100: 5001batch [01:51, 44.98batch/s, Train Accuracy=0.96, Train loss=0.088]
# Epoch 51/100: 5001batch [01:51, 44.97batch/s, Train Accuracy=0.96, Train loss=0.0889]
# Epoch 52/100: 5001batch [01:51, 45.02batch/s, Train Accuracy=0.96, Train loss=0.0889]
# Epoch 53/100: 5001batch [01:51, 45.05batch/s, Train Accuracy=0.96, Train loss=0.0902]
# Epoch 54/100: 5001batch [01:55, 43.25batch/s, Train Accuracy=0.961, Train loss=0.0888]
# Epoch 55/100: 5001batch [01:53, 43.93batch/s, Train Accuracy=0.961, Train loss=0.0885]
# Epoch 56/100: 5001batch [01:54, 43.86batch/s, Train Accuracy=0.961, Train loss=0.088]
# Epoch 57/100: 5001batch [01:53, 43.89batch/s, Train Accuracy=0.961, Train loss=0.0878]
# Epoch 58/100: 5001batch [01:53, 43.98batch/s, Train Accuracy=0.961, Train loss=0.088]
# Epoch 59/100: 5001batch [01:53, 43.90batch/s, Train Accuracy=0.961, Train loss=0.0854]
# Epoch 60/100: 5001batch [01:53, 43.93batch/s, Train Accuracy=0.961, Train loss=0.0882]
# Epoch 61/100: 5001batch [01:53, 43.92batch/s, Train Accuracy=0.961, Train loss=0.091]
# Epoch 62/100: 5001batch [01:53, 43.91batch/s, Train Accuracy=0.961, Train loss=0.087]
# Epoch 63/100: 5001batch [01:53, 43.94batch/s, Train Accuracy=0.961, Train loss=0.0883]
# Epoch 64/100: 5001batch [01:53, 43.99batch/s, Train Accuracy=0.961, Train loss=0.0868]
# Epoch 65/100: 5001batch [01:53, 43.97batch/s, Train Accuracy=0.961, Train loss=0.087]
# Epoch 66/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.962, Train loss=0.087]
# Epoch 67/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.962, Train loss=0.0874]
# Epoch 68/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.962, Train loss=0.0877]
# Epoch 69/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.962, Train loss=0.0868]
# Epoch 70/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.962, Train loss=0.0888]
# Epoch 71/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.962, Train loss=0.086]
# Epoch 72/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.962, Train loss=0.0844]
# Epoch 73/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.962, Train loss=0.0887]
# Epoch 74/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.962, Train loss=0.0852]
# Epoch 75/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.962, Train loss=0.0846]
# Epoch 76/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.962, Train loss=0.0866]
# Epoch 77/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.962, Train loss=0.0828]
# Epoch 78/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.962, Train loss=0.086]
# Epoch 79/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.962, Train loss=0.0849]
# Epoch 80/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.962, Train loss=0.0861]
# Epoch 81/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.963, Train loss=0.0827]
# Epoch 82/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.963, Train loss=0.0854]
# Epoch 83/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.963, Train loss=0.0843]
# Epoch 84/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.963, Train loss=0.0879]
# Epoch 85/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.963, Train loss=0.0876]
# Epoch 86/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.963, Train loss=0.0838]
# Epoch 87/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.963, Train loss=0.0833]
# Epoch 88/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.963, Train loss=0.0867]
# Epoch 89/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.963, Train loss=0.0846]
# Epoch 90/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.963, Train loss=0.0846]
# Epoch 91/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.963, Train loss=0.0869]
# Epoch 92/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.963, Train loss=0.0876]
# Epoch 93/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.963, Train loss=0.0876]
# Epoch 94/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.963, Train loss=0.0867]
# Epoch 95/100: 5001batch [01:57, 42.68batch/s, Train Accuracy=0.963, Train loss=0.0837]
# Epoch 96/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.963, Train loss=0.085]
# Epoch 97/100: 5001batch [01:57, 42.67batch/s, Train Accuracy=0.963, Train loss=0.0879]
# Epoch 98/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.963, Train loss=0.0847]
# Epoch 99/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.963, Train loss=0.0846]
# Epoch 100/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.963, Train loss=0.0865]
# The trained models have been saved as:
# fpm_models/fpm_add_2skip_worm3_180_deg.h5

# %%
points_path="./worm3_points_t1.csv"
model_name="fpm_add_2skip_worm3_10_deg"
deg = 10
num_epochs=100
match_model = FlexiblePointMatcherAdd(num_skip=2)

fpm_trainer = TrainFPM(points1_path=points_path, match_model=match_model, model_name=model_name, 
                       range_rotation_tgt=deg)
fpm_trainer.train(num_epochs=num_epochs, iteration=5000)
# Out:
# Epoch 1/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.96, Train loss=0.0593]
# Epoch 2/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.98, Train loss=0.0427]
# Epoch 3/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.982, Train loss=0.0387]
# Epoch 4/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.984, Train loss=0.0351]
# Epoch 5/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.985, Train loss=0.0342]
# Epoch 6/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.985, Train loss=0.0332]
# Epoch 7/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.986, Train loss=0.0311]
# Epoch 8/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.986, Train loss=0.03]
# Epoch 9/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.987, Train loss=0.0301]
# Epoch 10/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.987, Train loss=0.0299]
# Epoch 11/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.987, Train loss=0.0294]
# Epoch 12/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.987, Train loss=0.0285]
# Epoch 13/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.988, Train loss=0.0279]
# Epoch 14/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.988, Train loss=0.0267]
# Epoch 15/100: 5001batch [01:57, 42.54batch/s, Train Accuracy=0.988, Train loss=0.0274]
# Epoch 16/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.988, Train loss=0.0271]
# Epoch 17/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.988, Train loss=0.0267]
# Epoch 18/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.989, Train loss=0.0256]
# Epoch 19/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.989, Train loss=0.0259]
# Epoch 20/100: 5001batch [01:57, 42.54batch/s, Train Accuracy=0.989, Train loss=0.0256]
# Epoch 21/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.989, Train loss=0.0245]
# Epoch 22/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.989, Train loss=0.0244]
# Epoch 23/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.989, Train loss=0.0254]
# Epoch 24/100: 5001batch [01:57, 42.51batch/s, Train Accuracy=0.989, Train loss=0.0239]
# Epoch 25/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.989, Train loss=0.0247]
# Epoch 26/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.989, Train loss=0.0236]
# Epoch 27/100: 5001batch [01:57, 42.52batch/s, Train Accuracy=0.989, Train loss=0.0242]
# Epoch 28/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.99, Train loss=0.0233]
# Epoch 29/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.99, Train loss=0.0229]
# Epoch 30/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.99, Train loss=0.0233]
# Epoch 31/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.99, Train loss=0.0232]
# Epoch 32/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.99, Train loss=0.0239]
# Epoch 33/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.99, Train loss=0.0224]
# Epoch 34/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.99, Train loss=0.0224]
# Epoch 35/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.99, Train loss=0.0225]
# Epoch 36/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.99, Train loss=0.022]
# Epoch 37/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.991, Train loss=0.0217]
# Epoch 38/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.991, Train loss=0.0225]
# Epoch 39/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.991, Train loss=0.0224]
# Epoch 40/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.991, Train loss=0.0216]
# Epoch 41/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.991, Train loss=0.0222]
# Epoch 42/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.991, Train loss=0.0209]
# Epoch 43/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.991, Train loss=0.0213]
# Epoch 44/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.991, Train loss=0.0208]
# Epoch 45/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.991, Train loss=0.0215]
# Epoch 46/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.991, Train loss=0.0213]
# Epoch 47/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.991, Train loss=0.0217]
# Epoch 48/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.991, Train loss=0.0202]
# Epoch 49/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.991, Train loss=0.0208]
# Epoch 50/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.991, Train loss=0.0207]
# Epoch 51/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.991, Train loss=0.0206]
# Epoch 52/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.991, Train loss=0.0206]
# Epoch 53/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.992, Train loss=0.0204]
# Epoch 54/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.992, Train loss=0.0205]
# Epoch 55/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.992, Train loss=0.021]
# Epoch 56/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.992, Train loss=0.0205]
# Epoch 57/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.992, Train loss=0.0206]
# Epoch 58/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.992, Train loss=0.0199]
# Epoch 59/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.992, Train loss=0.0201]
# Epoch 60/100: 5001batch [01:57, 42.54batch/s, Train Accuracy=0.992, Train loss=0.0198]
# Epoch 61/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.992, Train loss=0.0198]
# Epoch 62/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.992, Train loss=0.0204]
# Epoch 63/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.992, Train loss=0.0191]
# Epoch 64/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.992, Train loss=0.0199]
# Epoch 65/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.993, Train loss=0.0192]
# Epoch 66/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.993, Train loss=0.019]
# Epoch 67/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.993, Train loss=0.0195]
# Epoch 68/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.993, Train loss=0.0195]
# Epoch 69/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.993, Train loss=0.0192]
# Epoch 70/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.993, Train loss=0.0186]
# Epoch 71/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.993, Train loss=0.0197]
# Epoch 72/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.993, Train loss=0.0189]
# Epoch 73/100: 5001batch [01:57, 42.54batch/s, Train Accuracy=0.993, Train loss=0.0188]
# Epoch 74/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.993, Train loss=0.0188]
# Epoch 75/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.993, Train loss=0.0186]
# Epoch 76/100: 5001batch [01:57, 42.52batch/s, Train Accuracy=0.993, Train loss=0.0186]
# Epoch 77/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.993, Train loss=0.0186]
# Epoch 78/100: 5001batch [01:57, 42.55batch/s, Train Accuracy=0.993, Train loss=0.0186]
# Epoch 79/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.993, Train loss=0.0183]
# Epoch 80/100: 5001batch [01:57, 42.52batch/s, Train Accuracy=0.993, Train loss=0.0189]
# Epoch 81/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.993, Train loss=0.0186]
# Epoch 82/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.994, Train loss=0.0187]
# Epoch 83/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.994, Train loss=0.0187]
# Epoch 84/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.994, Train loss=0.0187]
# Epoch 85/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.994, Train loss=0.0188]
# Epoch 86/100: 5001batch [01:57, 42.56batch/s, Train Accuracy=0.994, Train loss=0.0183]
# Epoch 87/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.994, Train loss=0.0177]
# Epoch 88/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.994, Train loss=0.0179]
# Epoch 89/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.994, Train loss=0.0178]
# Epoch 90/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.994, Train loss=0.0184]
# Epoch 91/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.994, Train loss=0.0183]
# Epoch 92/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.994, Train loss=0.0184]
# Epoch 93/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.994, Train loss=0.0174]
# Epoch 94/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.994, Train loss=0.0184]
# Epoch 95/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.994, Train loss=0.0179]
# Epoch 96/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.994, Train loss=0.0183]
# Epoch 97/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.994, Train loss=0.0182]
# Epoch 98/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.994, Train loss=0.0175]
# Epoch 99/100: 5001batch [01:57, 42.52batch/s, Train Accuracy=0.994, Train loss=0.018]
# Epoch 100/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.994, Train loss=0.0183]
# The trained models have been saved as:
# fpm_models/fpm_add_2skip_worm3_10_deg.h5

# %% [markdown]
# # points_path="./worm3_points_t1.csv"
# model_name="fpm_add_worm3_180_deg"
# deg = (-180, 180)
#
# fpm_trainer = TrainFPM(points1_path=points_path, model_type="add", model_name=model_name, range_rotation_ref=deg, range_rotation_tgt=deg)
# num_epochs=100
#
# fpm_trainer.train(num_epochs=num_epochs, iteration=5000)

# %%
points_path="./worm3_points_t1.csv"
model_name="fpm_add_2skip_worm3_90_deg"
deg = 90
num_epochs=100
match_model = FlexiblePointMatcherAdd(num_skip=2)

fpm_trainer = TrainFPM(points1_path=points_path, match_model=match_model, model_name=model_name, 
                       range_rotation_tgt=deg)
fpm_trainer.train(num_epochs=num_epochs, iteration=5000)
# Out:
# Epoch 1/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.895, Train loss=0.165]
# Epoch 2/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.937, Train loss=0.125]
# Epoch 3/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.944, Train loss=0.115]
# Epoch 4/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.948, Train loss=0.107]
# Epoch 5/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.951, Train loss=0.102]
# Epoch 6/100: 5001batch [01:57, 42.67batch/s, Train Accuracy=0.953, Train loss=0.0991]
# Epoch 7/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.954, Train loss=0.0985]
# Epoch 8/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.955, Train loss=0.0943]
# Epoch 9/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.956, Train loss=0.0929]
# Epoch 10/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.957, Train loss=0.093]
# Epoch 11/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.958, Train loss=0.0887]
# Epoch 12/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.959, Train loss=0.0868]
# Epoch 13/100: 5001batch [01:57, 42.67batch/s, Train Accuracy=0.959, Train loss=0.0867]
# Epoch 14/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.96, Train loss=0.0857]
# Epoch 15/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.96, Train loss=0.0873]
# Epoch 16/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.961, Train loss=0.0833]
# Epoch 17/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.961, Train loss=0.0806]
# Epoch 18/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.962, Train loss=0.0838]
# Epoch 19/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.962, Train loss=0.0811]
# Epoch 20/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.962, Train loss=0.0834]
# Epoch 21/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.963, Train loss=0.08]
# Epoch 22/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.963, Train loss=0.0797]
# Epoch 23/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.963, Train loss=0.0799]
# Epoch 24/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.963, Train loss=0.0801]
# Epoch 25/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.964, Train loss=0.0777]
# Epoch 26/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.964, Train loss=0.0783]
# Epoch 27/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.964, Train loss=0.0799]
# Epoch 28/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.964, Train loss=0.0795]
# Epoch 29/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.965, Train loss=0.0792]
# Epoch 30/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.965, Train loss=0.0786]
# Epoch 31/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.965, Train loss=0.0783]
# Epoch 32/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.965, Train loss=0.0768]
# Epoch 33/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.965, Train loss=0.0774]
# Epoch 34/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.965, Train loss=0.0752]
# Epoch 35/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.966, Train loss=0.0736]
# Epoch 36/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.966, Train loss=0.0741]
# Epoch 37/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.966, Train loss=0.0739]
# Epoch 38/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.966, Train loss=0.0731]
# Epoch 39/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.966, Train loss=0.073]
# Epoch 40/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.966, Train loss=0.0771]
# Epoch 41/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.966, Train loss=0.0765]
# Epoch 42/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.967, Train loss=0.0748]
# Epoch 43/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.967, Train loss=0.0744]
# Epoch 44/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.967, Train loss=0.0758]
# Epoch 45/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.967, Train loss=0.0757]
# Epoch 46/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.967, Train loss=0.0743]
# Epoch 47/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.967, Train loss=0.0716]
# Epoch 48/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.967, Train loss=0.0732]
# Epoch 49/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.967, Train loss=0.0729]
# Epoch 50/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.967, Train loss=0.0718]
# Epoch 51/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.968, Train loss=0.0693]
# Epoch 52/100: 5001batch [01:57, 42.68batch/s, Train Accuracy=0.968, Train loss=0.073]
# Epoch 53/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.968, Train loss=0.0722]
# Epoch 54/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.968, Train loss=0.0731]
# Epoch 55/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.968, Train loss=0.0715]
# Epoch 56/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.968, Train loss=0.0702]
# Epoch 57/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.968, Train loss=0.0708]
# Epoch 58/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.968, Train loss=0.073]
# Epoch 59/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.968, Train loss=0.0721]
# Epoch 60/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.968, Train loss=0.0722]
# Epoch 61/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.968, Train loss=0.0726]
# Epoch 62/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.968, Train loss=0.073]
# Epoch 63/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.969, Train loss=0.0721]
# Epoch 64/100: 5001batch [01:57, 42.67batch/s, Train Accuracy=0.969, Train loss=0.0717]
# Epoch 65/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.969, Train loss=0.0715]
# Epoch 66/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.969, Train loss=0.069]
# Epoch 67/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.969, Train loss=0.0702]
# Epoch 68/100: 5001batch [01:57, 42.64batch/s, Train Accuracy=0.969, Train loss=0.0719]
# Epoch 69/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.969, Train loss=0.0704]
# Epoch 70/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.969, Train loss=0.0695]
# Epoch 71/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.969, Train loss=0.0711]
# Epoch 72/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.969, Train loss=0.0716]
# Epoch 73/100: 5001batch [01:57, 42.54batch/s, Train Accuracy=0.969, Train loss=0.0727]
# Epoch 74/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.969, Train loss=0.0711]
# Epoch 75/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.969, Train loss=0.0696]
# Epoch 76/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.969, Train loss=0.0702]
# Epoch 77/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.969, Train loss=0.0699]
# Epoch 78/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.969, Train loss=0.0702]
# Epoch 79/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.97, Train loss=0.072]
# Epoch 80/100: 5001batch [01:57, 42.57batch/s, Train Accuracy=0.97, Train loss=0.0691]
# Epoch 81/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.97, Train loss=0.0714]
# Epoch 82/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.97, Train loss=0.0699]
# Epoch 83/100: 5001batch [01:57, 42.59batch/s, Train Accuracy=0.97, Train loss=0.0702]
# Epoch 84/100: 5001batch [01:57, 42.58batch/s, Train Accuracy=0.97, Train loss=0.0703]
# Epoch 85/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.97, Train loss=0.0705]
# Epoch 86/100: 5001batch [01:57, 42.61batch/s, Train Accuracy=0.97, Train loss=0.07]
# Epoch 87/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.97, Train loss=0.0724]
# Epoch 88/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.97, Train loss=0.069]
# Epoch 89/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.97, Train loss=0.069]
# Epoch 90/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.97, Train loss=0.0663]
# Epoch 91/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.97, Train loss=0.067]
# Epoch 92/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.97, Train loss=0.0674]
# Epoch 93/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.97, Train loss=0.068]
# Epoch 94/100: 5001batch [01:57, 42.65batch/s, Train Accuracy=0.97, Train loss=0.0695]
# Epoch 95/100: 5001batch [01:57, 42.67batch/s, Train Accuracy=0.97, Train loss=0.0695]
# Epoch 96/100: 5001batch [01:57, 42.60batch/s, Train Accuracy=0.97, Train loss=0.0672]
# Epoch 97/100: 5001batch [01:57, 42.66batch/s, Train Accuracy=0.97, Train loss=0.0668]
# Epoch 98/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.97, Train loss=0.0669]
# Epoch 99/100: 5001batch [01:57, 42.62batch/s, Train Accuracy=0.97, Train loss=0.0711]
# Epoch 100/100: 5001batch [01:57, 42.63batch/s, Train Accuracy=0.97, Train loss=0.0675]
# The trained models have been saved as:
# fpm_models/fpm_add_2skip_worm3_90_deg.h5
